# %%
import pandas as pd

# %%
data = pd.read_csv('/content/Students_Performance.csv')

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data.describe()
# Out:
#         math score  reading score  writing score
# count  1000.000000    1000.000000    1000.000000
# mean     66.001000      69.195000      68.119000
# std      15.569567      14.706436      15.226381
# min       0.000000      17.000000      10.000000
# 25%      57.000000      59.000000      58.000000
# 50%      66.000000      70.000000      69.000000
# 75%      77.000000      79.250000      79.000000
# max     100.000000     100.000000     100.000000

# %% [markdown]
#  Number of males and females

# %%
data['gender'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
gender_list = data['gender'].unique()

# %%
for gender in gender_list:
  print('number of',gender,'students is',data['gender'][data['gender']==gender].count())
# Out:
# number of female students is 518
# number of male students is 482

# %% [markdown]
# Different parental level of education

# %%
parent_edu_list = data['parental level of education'].unique()

# %%
for parent_edu in parent_edu_list:
    print('Number of students in',parent_edu,'is',data['race/ethnicity'][data['parental level of education'] == parent_edu].count())
# Out:
# Number of students in some high school is 179
# Number of students in high school is 196
# Number of students in some college is 226
# Number of students in associate's degree is 222
# Number of students in bachelor's degree is 118
# Number of students in master's degree is 59

# %% [markdown]
# .

# %%
import numpy as np

# %%
import seaborn as sns

# %%
print('Avrage Maths Score : ',data['math score'].mean())
print('Avrage Reading Score : ',data['reading score'].mean())
print('Avrage Writing Score : ',data['writing score'].mean())
# Out:
# Avrage Maths Score :  66.001
# Avrage Reading Score :  69.195
# Avrage Writing Score :  68.119

# %% [markdown]
# Average score of students by gender

# %%
data.groupby('gender').mean().reset_index()
# Out:
# <ipython-input-27-a263484bfa7b>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('gender').mean().reset_index()
#    gender  math score  reading score  writing score
# 0  female   63.376448      72.590734      72.467181
# 1    male   68.821577      65.545643      63.446058

# %% [markdown]
# Average score of students by test preparation course

# %%
data.groupby('test preparation course').mean().reset_index()
# Out:
# <ipython-input-29-9dfa5bd8b52c>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('test preparation course').mean().reset_index()
#   test preparation course  math score  reading score  writing score
# 0               completed    69.96648      74.175978      74.684358
# 1                    none    63.78972      66.417445      64.457944

# %% [markdown]
# Score variation by gender

# %%
data.groupby('gender').mean().reset_index().sort_values('math score', ascending = False)
# Out:
# <ipython-input-30-12a90446008d>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('gender').mean().reset_index().sort_values('math score', ascending = False)
#    gender  math score  reading score  writing score
# 1    male   68.821577      65.545643      63.446058
# 0  female   63.376448      72.590734      72.467181

# %% [markdown]
# Score variation by test preparation course

# %%
data.groupby('test preparation course').mean().reset_index().sort_values('math score', ascending = False)
# Out:
# <ipython-input-31-f790d538db40>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('test preparation course').mean().reset_index().sort_values('math score', ascending = False)
#   test preparation course  math score  reading score  writing score
# 0               completed    69.96648      74.175978      74.684358
# 1                    none    63.78972      66.417445      64.457944
